# %%
import pandas as pd

# %%
data = pd.read_csv("loan_data_2015.csv")
print(data.describe)
# Out:
# <bound method NDFrame.describe of               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0       65612389   70235126       1000         1000             1000
# 1       63527563   67870358       1000         1000             1000
# 2       60256601   64233368       1000         1000             1000
# 3       66642400   71368157       1200         1200             1200
# 4       38599820   41383735       1400         1400             1400
# ...          ...        ...        ...          ...              ...
# 421088  61762386   65932106      35000        35000            34975
# 421089  61360078   65478840      35000        35000            34975
# 421090  59152137   63039922      35000        35000            34975
# 421091  57950487   61754206      35000        35000            34900
# 421092  55961482   59623319      35000        35000            34600
#
#         int_rate  installment  annual_inc  total_pymnt
# ...

# %%
print(data.head())
print(data.tail())
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# 0  65612389   70235126       1000         1000             1000      5.32
# 1  63527563   67870358       1000         1000             1000      5.32
# 2  60256601   64233368       1000         1000             1000      5.32
# 3  66642400   71368157       1200         1200             1200      5.32
# 4  38599820   41383735       1400         1400             1400      6.03
#
#    installment  annual_inc  total_pymnt
# 0        30.12     80000.0        59.94
# 1        30.12     47000.0        59.94
# 2        30.12     92000.0       119.89
# 3        36.14    105000.0        35.43
# 4        42.61     56800.0       339.94
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 421088  61762386   65932106      35000        35000            34975
# 421089  61360078   65478840      35000        35000            34975
# 421090  59152137   63039922      35000        35000            34975
# ...

# %%
loans_grater_than_thresold = data[data['loan_amnt']>3500]
print(loans_grater_than_thresold)
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 70      67295634   72097356       3600         3600             3600
# 71      67065347   71866063       3600         3600             3600
# 72      63475877   67818631       3600         3600             3600
# 73      63285169   67526909       3600         3600             3600
# 74      55938183   59599921       3600         3600             3600
# ...          ...        ...        ...          ...              ...
# 421088  61762386   65932106      35000        35000            34975
# 421089  61360078   65478840      35000        35000            34975
# 421090  59152137   63039922      35000        35000            34975
# 421091  57950487   61754206      35000        35000            34900
# 421092  55961482   59623319      35000        35000            34600
#
#         int_rate  installment  annual_inc  total_pymnt
# 70          5.32       108.42     90000.0       107.36
# ...
