# %%
import numpy as np

# %%
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],
    [2, 120000, 140000, 160000, 190000],
    [3, 200000, 230000, 260000, 300000],
    [4, 180000, 210000, 240000, 270000],
    [5, 160000, 185000, 205000, 230000]
])

print("=== Zomato Sales Analysis ===")
print("\nSales Dimmension: ", sales_data.shape)
print("\nFirst 3 resturant sales: ", sales_data[1,3])
# Out:
# === Zomato Sales Analysis ===
#
# Sales Dimmension:  (5, 5)
#
# First 3 resturant sales:  [     4 180000 210000 240000 270000]
