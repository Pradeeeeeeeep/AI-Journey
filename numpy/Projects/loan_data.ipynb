# %%
import numpy as np

# %%
data = np.loadtxt(
    "loan_data_2015.csv",
    delimiter=",",
    skiprows=1,
    dtype=str,
    quotechar='"'
)

# %%
total_loan_distributed = np.sum(data[:,2].astype(int))
print("Total loan distributed: ", total_loan_distributed)
# Out:
# Total loan distributed:  6417429150

# %%
average_loan_amt = np.mean(data[:,2].astype(int))
print("Average loan amount: ", average_loan_amt)
# Out:
# Average loan amount:  15240.222639134616

# %%
min_annual_income = np.min(data[:,7].astype(float))
print("Minimum annual income: ", min_annual_income)
# Out:
# Minimum annual income:  0.0

# %%
max_annual_inc = np.max(data[:, 7].astype(float))
print("Maximum annual income", max_annual_inc)
# Out:
# Maximum annual income 9500000.0

# %%
avg_annual_inc = np.mean(data[:,7].astype(float))
print("Average annual income: ", average_loan_amt)
# Out:
# Average annual income:  15240.222639134616

# %%
min_instalment = np.min(data[:,6].astype(float))
print("The minimum instalment: ", min_instalment)
# Out:
# The minimum instalment:  30.12

# %%
max_instalment = np.max(data[:,6].astype(float))
print("The maximum instalment: ", max_instalment)
# Out:
# The maximum instalment:  1445.46

# %%
max_loan = np.max(data[:,2].astype(float))
min_loan = np.min(data[:,2].astype(float))
print("Maximum loan distributed: ", max_loan)
print("Minimu loan distributed: ", min_loan)
# Out:
# Maximum loan distributed:  35000.0
# Minimu loan distributed:  1000.0

# %%
loan = data[:,2].astype(float)

loan[loan > 10000]

print(loan)
# Out:
# [ 1000.  1000.  1000. ... 35000. 35000. 35000.]
